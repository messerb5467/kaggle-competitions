# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
train = pd.read_csv('train.csv')

# %%
base_train = train[['SalePrice', 
                    'OverallQual', 
                    'GrLivArea', 
                    'GarageCars', 
                    'GarageArea', 
                    'TotalBsmtSF', 
                    '1stFlrSF', 
                    'FullBath']].copy()

# %%
sns.pairplot(base_train)

# %%
transformed_data = StandardScaler().fit_transform(base_train)

# %%
type(transformed_data)
# Out:
# numpy.ndarray

# %%
transformed_data
# Out:
# array([[ 0.34727322,  0.65147924,  0.37033344, ..., -0.45930254,
#         -0.79343379,  0.78974052],
#        [ 0.00728832, -0.07183611, -0.48251191, ...,  0.46646492,
#          0.25714043,  0.78974052],
#        [ 0.53615372,  0.65147924,  0.51501256, ..., -0.31336875,
#         -0.62782603,  0.78974052],
#        ...,
#        [ 1.07761115,  0.65147924,  1.56964722, ...,  0.21564122,
#          0.06565646,  0.78974052],
#        [-0.48852299, -0.79515147, -0.83278768, ...,  0.04690528,
#         -0.21898188, -1.02604084],
#        [-0.42084081, -0.79515147, -0.49393395, ...,  0.45278362,
#          0.2416147 , -1.02604084]])

# %%
transformed_df = pd.DataFrame(data=transformed_data, columns=base_train.columns)

# %%
sns.pairplot(transformed_df)

# %%
import numpy as np
base_train['SalesPriceLog'] = np.log(base_train['SalePrice'])

# %%
sns.histplot(base_train['SalesPriceLog'])
# Out:
# <AxesSubplot:xlabel='SalesPriceLog', ylabel='Count'>

# %%
base_train['GarageAreaLog'] = np.log(base_train['GarageArea'])
# Out:
# /home/messerb/anaconda3/envs/kaggle-env/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
